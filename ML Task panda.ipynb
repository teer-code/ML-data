# %%
import pandas as pd 
import numpy as np

# %%
df=pd.read_csv("ML_task/weatherAUS.csv")

# %%
df
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 145455  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 145456  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 145457  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 145458  2017-06-24    Uluru      7.8     27.0       0.0          NaN
# 145459  2017-06-25    Uluru     14.9      NaN       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# ...

# %%
avgmaxtemp=df['MaxTemp'].mean()

# %%
avgmaxtemp
# Out:
# 23.221348275647003

# %%
avgmintemp=df['MinTemp'].mean()

# %%
avgmintemp
# Out:
# 12.19403438096871

# %%
filt=df['Location']=='Cobar'

# %%
df.loc[filt]['MaxTemp'].mean()
# Out:
# 25.870093147039235

# %%
count=df['Sunshine'].isnull().sum()

# %%
count1=df['Evaporation'].isnull().sum()

# %%
count1
# Out:
# 62790

# %%
count
# Out:
# 69835

# %%
df
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 145455  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 145456  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 145457  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 145458  2017-06-24    Uluru      7.8     27.0       0.0          NaN
# 145459  2017-06-25    Uluru     14.9      NaN       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# ...

# %%
df['Evaporation']=df['Evaporation'].fillna(avev)

# %%
df
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6     5.468232
# 1       2008-12-02   Albury      7.4     25.1       0.0     5.468232
# 2       2008-12-03   Albury     12.9     25.7       0.0     5.468232
# 3       2008-12-04   Albury      9.2     28.0       0.0     5.468232
# 4       2008-12-05   Albury     17.5     32.3       1.0     5.468232
# ...            ...      ...      ...      ...       ...          ...
# 145455  2017-06-21    Uluru      2.8     23.4       0.0     5.468232
# 145456  2017-06-22    Uluru      3.6     25.3       0.0     5.468232
# 145457  2017-06-23    Uluru      5.4     26.9       0.0     5.468232
# 145458  2017-06-24    Uluru      7.8     27.0       0.0     5.468232
# 145459  2017-06-25    Uluru     14.9      NaN       0.0     5.468232
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# ...

# %%
avev=df['Evaporation'].mean()

# %%
avev
# Out:
# 5.468231522922464

# %%
df.dropna(axis=1,how='any')
# Out:
#               Date Location
# 0       2008-12-01   Albury
# 1       2008-12-02   Albury
# 2       2008-12-03   Albury
# 3       2008-12-04   Albury
# 4       2008-12-05   Albury
# ...            ...      ...
# 145455  2017-06-21    Uluru
# 145456  2017-06-22    Uluru
# 145457  2017-06-23    Uluru
# 145458  2017-06-24    Uluru
# 145459  2017-06-25    Uluru
#
# [145460 rows x 2 columns]

# %%
df.drop(['Date'],axis=1)
# Out:
#        Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0        Albury     13.4     22.9       0.6          NaN       NaN
# 1        Albury      7.4     25.1       0.0          NaN       NaN
# 2        Albury     12.9     25.7       0.0          NaN       NaN
# 3        Albury      9.2     28.0       0.0          NaN       NaN
# 4        Albury     17.5     32.3       1.0          NaN       NaN
# ...         ...      ...      ...       ...          ...       ...
# 145455    Uluru      2.8     23.4       0.0          NaN       NaN
# 145456    Uluru      3.6     25.3       0.0          NaN       NaN
# 145457    Uluru      5.4     26.9       0.0          NaN       NaN
# 145458    Uluru      7.8     27.0       0.0          NaN       NaN
# 145459    Uluru     14.9      NaN       0.0          NaN       NaN
#
#        WindGustDir  WindGustSpeed WindDir9am WindDir3pm  ...  Humidity9am  \
# 0                W           44.0          W        WNW  ...         71.0
# ...

# %%
    i=input("enter location")
    country_grp=df.groupby(['Location'])
    country_grp.get_group(i);
# Out:
# enter locationUluru

# %%
    i=input("enter location")
    fil1=df['Location']==i
    df.loc[fil1]
# Out:
# enter locationUluru
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 143882  2013-03-01    Uluru     19.7     30.0       0.8          NaN
# 143883  2013-03-02    Uluru     21.6     33.1       0.0          NaN
# 143884  2013-03-03    Uluru     21.3     36.1       0.0          NaN
# 143885  2013-03-04    Uluru     22.9     37.7       0.0          NaN
# 143886  2013-03-05    Uluru     24.0     39.0       0.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 145455  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 145456  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 145457  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 145458  2017-06-24    Uluru      7.8     27.0       0.0          NaN
# 145459  2017-06-25    Uluru     14.9      NaN       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# ...

# %%
# Out:
# enter locationUluru
